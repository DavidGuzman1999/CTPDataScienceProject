# %%
import geopy
from geopy.geocoders import Nominatim
from geopy.extra.rate_limiter import RateLimiter

import pandas as pd

# %%
df = pd.read_csv("Data/NYPD_Complaint_Data_Current__Year_To_Date.csv")
df.head()
# Out:
#    CMPLNT_NUM  ADDR_PCT_CD   BORO_NM CMPLNT_FR_DT CMPLNT_FR_TM CMPLNT_TO_DT  \
# 0   758521794           67       NaN   03/07/2021     01:50:00          NaN
# 1   696896951           60       NaN   03/26/2021     18:40:00          NaN
# 2   972479923           75  BROOKLYN   03/27/2021     15:55:00   03/27/2021
# 3   109344500           77  BROOKLYN   03/28/2021     11:10:00   03/28/2021
# 4   673945415           23       NaN   03/29/2021     23:13:00          NaN
#
#   CMPLNT_TO_TM CRM_ATPT_CPTD_CD HADEVELOPT  HOUSING_PSA  ...  \
# 0          NaN        COMPLETED        NaN          NaN  ...
# 1          NaN        COMPLETED        NaN          NaN  ...
# 2     16:00:00        COMPLETED        NaN          NaN  ...
# 3     11:23:00        COMPLETED        NaN          NaN  ...
# 4          NaN        COMPLETED        NaN          NaN  ...
#
#    TRANSIT_DISTRICT VIC_AGE_GROUP        VIC_RACE VIC_SEX X_COORD_CD  \
# ...

# %%
df.shape
# Out:
# (204646, 36)

# %%
# creating a new dataframe with just lat and long 
df_latLong = df[['Latitude', "Longitude"]].copy()
df_latLong.head()
# Out:
#     Latitude  Longitude
# 0  40.654223 -73.911563
# 1  40.575443 -73.987795
# 2  40.678643 -73.867543
# 3  40.668584 -73.926980
# 4  40.793026 -73.942156

# %%
print (df_latLong.shape)
# Out:
# (204646, 2)

# %%
geolocator = geopy.Nominatim(user_agent="check_1")

# %%
def get_zip_code(x):
    location = geolocator.reverse("{}, {}".format(x["Latitude"],x["Longitude"]))
    return location.raw["address"]["postcode"]

# %%
print(df.iloc[0]["zipcode"])
# Out:
# 11212

# %%
df_latLong["zipcode"] = df[0:100].apply(lambda x: get_zip_code(x), axis=1)

# %%
df_latLong.head()
# Out:
#     Latitude  Longitude zipcode
# 0  40.654223 -73.911563   11212
# 1  40.575443 -73.987795   11224
# 2  40.678643 -73.867543   11208
# 3  40.668584 -73.926980   11213
# 4  40.793026 -73.942156   10029

# %%
zip_input = input("Enter your zip code ")
# Out:
# Enter your zip code11105

# %%
print(zip_input)
# Out:
# 11105

# %%
select_condition = df["zipcode"] == "11105"

# %%
df[select_condition]
# Out:
#      CMPLNT_NUM  ADDR_PCT_CD BORO_NM CMPLNT_FR_DT CMPLNT_FR_TM CMPLNT_TO_DT  \
# 496   687423374          114  QUEENS   03/22/2021     06:00:00   03/22/2021
# 620   386273319          114  QUEENS   03/20/2021     04:00:00   03/20/2021
# 631   217149255          114  QUEENS   03/21/2021     18:00:00   03/25/2021
# 866   601300585          114  QUEENS   10/16/2020     17:30:00   03/25/2021
#
#     CMPLNT_TO_TM CRM_ATPT_CPTD_CD HADEVELOPT  HOUSING_PSA  ...  VIC_AGE_GROUP  \
# 496     13:00:00        COMPLETED        NaN          NaN  ...          25-44
# 620     05:00:00        COMPLETED        NaN          NaN  ...          45-64
# 631     09:00:00        COMPLETED        NaN          NaN  ...          45-64
# 866     20:09:00        COMPLETED        NaN          NaN  ...        UNKNOWN
#
#                      VIC_RACE  VIC_SEX X_COORD_CD Y_COORD_CD   Latitude  \
# 496                     WHITE        M    1009017     222644  40.777756
# ...

# %%
df.columns
# Out:
# Index(['CMPLNT_NUM', 'ADDR_PCT_CD', 'BORO_NM', 'CMPLNT_FR_DT', 'CMPLNT_FR_TM',
#        'CMPLNT_TO_DT', 'CMPLNT_TO_TM', 'CRM_ATPT_CPTD_CD', 'HADEVELOPT',
#        'HOUSING_PSA', 'JURISDICTION_CODE', 'JURIS_DESC', 'KY_CD', 'LAW_CAT_CD',
#        'LOC_OF_OCCUR_DESC', 'OFNS_DESC', 'PARKS_NM', 'PATROL_BORO', 'PD_CD',
#        'PD_DESC', 'PREM_TYP_DESC', 'RPT_DT', 'STATION_NAME', 'SUSP_AGE_GROUP',
#        'SUSP_RACE', 'SUSP_SEX', 'TRANSIT_DISTRICT', 'VIC_AGE_GROUP',
#        'VIC_RACE', 'VIC_SEX', 'X_COORD_CD', 'Y_COORD_CD', 'Latitude',
#        'Longitude', 'Lat_Lon', 'New Georeferenced Column', 'zipcode'],
#       dtype='object')

# %%
df_latLong[select_condition].zipcode.count()

# %%
select_condition = df["zipcode"] == "11105"
df_zip = df[select_condition]
df_zip.OFNS_DESC.value_counts().reset_index()
df_zip
# Out:
#      CMPLNT_NUM  ADDR_PCT_CD BORO_NM CMPLNT_FR_DT CMPLNT_FR_TM CMPLNT_TO_DT  \
# 496   687423374          114  QUEENS   03/22/2021     06:00:00   03/22/2021
# 620   386273319          114  QUEENS   03/20/2021     04:00:00   03/20/2021
# 631   217149255          114  QUEENS   03/21/2021     18:00:00   03/25/2021
# 866   601300585          114  QUEENS   10/16/2020     17:30:00   03/25/2021
#
#     CMPLNT_TO_TM CRM_ATPT_CPTD_CD HADEVELOPT  HOUSING_PSA  ...  VIC_AGE_GROUP  \
# 496     13:00:00        COMPLETED        NaN          NaN  ...          25-44
# 620     05:00:00        COMPLETED        NaN          NaN  ...          45-64
# 631     09:00:00        COMPLETED        NaN          NaN  ...          45-64
# 866     20:09:00        COMPLETED        NaN          NaN  ...        UNKNOWN
#
#                      VIC_RACE  VIC_SEX X_COORD_CD Y_COORD_CD   Latitude  \
# 496                     WHITE        M    1009017     222644  40.777756
# ...

# %%
df_latLong[0:100]
# Out:
#      Latitude  Longitude zipcode
# 0   40.853507 -73.882203   10460
# 1   40.696329 -73.937711   11206
# 2   40.805364 -73.937663   10035
# 3   40.892351 -73.856440   10466
# 4   40.887303 -73.845167   10466
# ..        ...        ...     ...
# 95  40.678916 -73.823446   11420
# 96  40.741133 -73.901088   11377
# 97  40.779380 -73.799027   11357
# 98  40.615352 -74.067065   10305
# 99  40.647832 -74.087015   10302
#
# [100 rows x 3 columns]

# %%
# so far the data only has zipcodes for 100 rows, need to run function to make sure the zipcodes gets to all the lat and longs

# %% [markdown]
# ### Zip Code Funtion 2.0

# %%
geocoder = Nominatim(user_agent = 'check_1')
geocode = RateLimiter(geocoder.geocode, min_delay_seconds = 1,   return_value_on_exception = None)

# %%
def get_zip_code2(x):
    location = geocode.reverse("{},{}".format(x["Latitude"], x["Longitude"]))
    #location = geocode.reverse("{}, {}".format(x["Latitude"],x["Longitude"]))
    return location.raw["address"]["postcode"]

# %%
def get_zipcode3(df, geolocator, Latitude, Longitude):
    location = geolocator.reverse((df[Latitude], df[Longitude]))
    return location.raw['address']['postcode']


#geolocator = geopy.Nominatim(user_agent='check_1')

# %%
df["zipcode"] = df[0:1000].apply(lambda x: get_zip_code2(x), axis=1)

# %%
df["zipcode"] = df.apply(get_zipcode, axis=1, geolocator=geolocator, Latitude='Latitude', Longitude='Longitude')
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/urllib3/connection.py in _new_conn(self)
#     158             conn = connection.create_connection(
# --> 159                 (self._dns_host, self.port), self.timeout, **extra_kw)
#     160
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      56
# ---> 57     for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      58         af, socktype, proto, canonname, sa = res
#
# ~/anaconda3/lib/python3.7/socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     747     addrlist = []
# --> 748     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     749         af, socktype, proto, canonname, sa = res
#
# ...
