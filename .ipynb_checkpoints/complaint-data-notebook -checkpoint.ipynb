# %%
import pandas as pd
import geopy
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import matplotlib.cm as cm
import matplotlib as mpl
from matplotlib.gridspec import GridSpec
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv("Data/NYPD_Complaint_Data_Current__Year_To_Date.csv")

# %%
df.head()
# Out:
#    CMPLNT_NUM  ADDR_PCT_CD   BORO_NM CMPLNT_FR_DT CMPLNT_FR_TM CMPLNT_TO_DT  \
# 0   758521794           67       NaN   03/07/2021     01:50:00          NaN
# 1   696896951           60       NaN   03/26/2021     18:40:00          NaN
# 2   972479923           75  BROOKLYN   03/27/2021     15:55:00   03/27/2021
# 3   109344500           77  BROOKLYN   03/28/2021     11:10:00   03/28/2021
# 4   673945415           23       NaN   03/29/2021     23:13:00          NaN
#
#   CMPLNT_TO_TM CRM_ATPT_CPTD_CD HADEVELOPT  HOUSING_PSA  ...  \
# 0          NaN        COMPLETED        NaN          NaN  ...
# 1          NaN        COMPLETED        NaN          NaN  ...
# 2     16:00:00        COMPLETED        NaN          NaN  ...
# 3     11:23:00        COMPLETED        NaN          NaN  ...
# 4          NaN        COMPLETED        NaN          NaN  ...
#
#    TRANSIT_DISTRICT VIC_AGE_GROUP        VIC_RACE VIC_SEX X_COORD_CD  \
# 0               NaN         18-24           BLACK       M    1008789
# 1               NaN         25-44  BLACK HISPANIC       M     987641
# 2               NaN         25-44           BLACK       F    1020990
# 3               NaN       UNKNOWN         UNKNOWN       D    1004507
# 4               NaN         25-44  WHITE HISPANIC       M    1000267
#
#   Y_COORD_CD   Latitude  Longitude                                   Lat_Lon  \
# 0     177637  40.654223 -73.911563  (40.654223423000076, -73.91156340899995)
# 1     148923  40.575443 -73.987795   (40.57544276900006, -73.98779476299995)
# 2     186549  40.678643 -73.867543        (40.67864264400004, -73.867542755)
# 3     182865  40.668584 -73.926980   (40.66858395700007, -73.92697993199994)
# 4     228200  40.793026 -73.942156  (40.793026087000044, -73.94215617799993)
#
#                         New Georeferenced Column
# 0  POINT (-73.91156340899995 40.654223423000076)
# 1   POINT (-73.98779476299995 40.57544276900006)
# 2        POINT (-73.867542755 40.67864264400004)
# 3   POINT (-73.92697993199994 40.66858395700007)
# 4  POINT (-73.94215617799993 40.793026087000044)
#
# [5 rows x 36 columns]

# %%
print(df.shape)
# Out:
# (204646, 36)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 204646 entries, 0 to 204645
# Data columns (total 36 columns):
# CMPLNT_NUM                  204646 non-null int64
# ADDR_PCT_CD                 204646 non-null int64
# BORO_NM                     204261 non-null object
# CMPLNT_FR_DT                204646 non-null object
# CMPLNT_FR_TM                204646 non-null object
# CMPLNT_TO_DT                186101 non-null object
# CMPLNT_TO_TM                186165 non-null object
# CRM_ATPT_CPTD_CD            204483 non-null object
# HADEVELOPT                  802 non-null object
# HOUSING_PSA                 15976 non-null float64
# JURISDICTION_CODE           204437 non-null float64
# JURIS_DESC                  204646 non-null object
# KY_CD                       204646 non-null int64
# LAW_CAT_CD                  204646 non-null object
# LOC_OF_OCCUR_DESC           171200 non-null object
# OFNS_DESC                   204639 non-null object
# PARKS_NM                    1255 non-null object
# PATROL_BORO                 204437 non-null object
# PD_CD                       204437 non-null float64
# PD_DESC                     204437 non-null object
# PREM_TYP_DESC               204106 non-null object
# RPT_DT                      204646 non-null object
# STATION_NAME                4044 non-null object
# SUSP_AGE_GROUP              163561 non-null object
# SUSP_RACE                   163561 non-null object
# SUSP_SEX                    163561 non-null object
# TRANSIT_DISTRICT            4044 non-null float64
# VIC_AGE_GROUP               204646 non-null object
# VIC_RACE                    204614 non-null object
# VIC_SEX                     204646 non-null object
# X_COORD_CD                  204646 non-null int64
# Y_COORD_CD                  204646 non-null int64
# Latitude                    204646 non-null float64
# Longitude                   204646 non-null float64
# Lat_Lon                     204646 non-null object
# New Georeferenced Column    204646 non-null object
# dtypes: float64(6), int64(5), object(25)
# memory usage: 56.2+ MB

# %%
df.isnull().sum()
# Out:
# CMPLNT_NUM                       0
# ADDR_PCT_CD                      0
# BORO_NM                        385
# CMPLNT_FR_DT                     0
# CMPLNT_FR_TM                     0
# CMPLNT_TO_DT                 18545
# CMPLNT_TO_TM                 18481
# CRM_ATPT_CPTD_CD               163
# HADEVELOPT                  203844
# HOUSING_PSA                 188670
# JURISDICTION_CODE              209
# JURIS_DESC                       0
# KY_CD                            0
# LAW_CAT_CD                       0
# LOC_OF_OCCUR_DESC            33446
# OFNS_DESC                        7
# PARKS_NM                    203391
# PATROL_BORO                    209
# PD_CD                          209
# PD_DESC                        209
# PREM_TYP_DESC                  540
# RPT_DT                           0
# STATION_NAME                200602
# SUSP_AGE_GROUP               41085
# SUSP_RACE                    41085
# SUSP_SEX                     41085
# TRANSIT_DISTRICT            200602
# VIC_AGE_GROUP                    0
# VIC_RACE                        32
# VIC_SEX                          0
# X_COORD_CD                       0
# Y_COORD_CD                       0
# Latitude                         0
# Longitude                        0
# Lat_Lon                          0
# New Georeferenced Column         0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df["STATION_NAME"].fillna("No transit station name", inplace = True)
df["HOUSING_PSA"].fillna("No level development code", inplace = True)
df["PARKS_NM"].fillna("Not aplicable", inplace = True)
df["TRANSIT_DISTRICT"].fillna("No data available", inplace = True)
df["HADEVELOPT"].fillna("Not aplicable", inplace = True)

# %%
df.columns = df.columns.str.lower()
df.columns = df.columns.str.replace(' ','_')
df.columns
# Out:
# Index(['cmplnt_num', 'addr_pct_cd', 'boro_nm', 'cmplnt_fr_dt', 'cmplnt_fr_tm',
#        'cmplnt_to_dt', 'cmplnt_to_tm', 'crm_atpt_cptd_cd', 'hadevelopt',
#        'housing_psa', 'jurisdiction_code', 'juris_desc', 'ky_cd', 'law_cat_cd',
#        'loc_of_occur_desc', 'ofns_desc', 'parks_nm', 'patrol_boro', 'pd_cd',
#        'pd_desc', 'prem_typ_desc', 'rpt_dt', 'station_name', 'susp_age_group',
#        'susp_race', 'susp_sex', 'transit_district', 'vic_age_group',
#        'vic_race', 'vic_sex', 'x_coord_cd', 'y_coord_cd', 'latitude',
#        'longitude', 'lat_lon', 'new_georeferenced_column'],
#       dtype='object')

# %%
df.head()
# Out:
#    cmplnt_num  addr_pct_cd   boro_nm cmplnt_fr_dt cmplnt_fr_tm cmplnt_to_dt  \
# 0   758521794           67       NaN   03/07/2021     01:50:00          NaN
# 1   696896951           60       NaN   03/26/2021     18:40:00          NaN
# 2   972479923           75  BROOKLYN   03/27/2021     15:55:00   03/27/2021
# 3   109344500           77  BROOKLYN   03/28/2021     11:10:00   03/28/2021
# 4   673945415           23       NaN   03/29/2021     23:13:00          NaN
#
#   cmplnt_to_tm crm_atpt_cptd_cd     hadevelopt                housing_psa  \
# 0          NaN        COMPLETED  Not aplicable  No level development code
# 1          NaN        COMPLETED  Not aplicable  No level development code
# 2     16:00:00        COMPLETED  Not aplicable  No level development code
# 3     11:23:00        COMPLETED  Not aplicable  No level development code
# 4          NaN        COMPLETED  Not aplicable  No level development code
#
#    ...   transit_district vic_age_group        vic_race vic_sex x_coord_cd  \
# 0  ...  No data available         18-24           BLACK       M    1008789
# 1  ...  No data available         25-44  BLACK HISPANIC       M     987641
# 2  ...  No data available         25-44           BLACK       F    1020990
# 3  ...  No data available       UNKNOWN         UNKNOWN       D    1004507
# 4  ...  No data available         25-44  WHITE HISPANIC       M    1000267
#
#   y_coord_cd   latitude  longitude                                   lat_lon  \
# 0     177637  40.654223 -73.911563  (40.654223423000076, -73.91156340899995)
# 1     148923  40.575443 -73.987795   (40.57544276900006, -73.98779476299995)
# 2     186549  40.678643 -73.867543        (40.67864264400004, -73.867542755)
# 3     182865  40.668584 -73.926980   (40.66858395700007, -73.92697993199994)
# 4     228200  40.793026 -73.942156  (40.793026087000044, -73.94215617799993)
#
#                         new_georeferenced_column
# 0  POINT (-73.91156340899995 40.654223423000076)
# 1   POINT (-73.98779476299995 40.57544276900006)
# 2        POINT (-73.867542755 40.67864264400004)
# 3   POINT (-73.92697993199994 40.66858395700007)
# 4  POINT (-73.94215617799993 40.793026087000044)
#
# [5 rows x 36 columns]

# %%
# Find/Delete the duplicate
condition = df['cmplnt_num'] == 927482064
duplicate_key_num = df[condition]
duplicate_key_num
# Out:
#         cmplnt_num  addr_pct_cd    boro_nm cmplnt_fr_dt cmplnt_fr_tm  \
# 28218    927482064           19  MANHATTAN   03/02/2021     17:20:00
# 202348   927482064           19  MANHATTAN   04/02/2021     17:00:00
#
#        cmplnt_to_dt cmplnt_to_tm crm_atpt_cptd_cd     hadevelopt  \
# 28218    03/02/2021     17:20:00        COMPLETED  Not aplicable
# 202348   04/02/2021     17:20:00        COMPLETED  Not aplicable
#
#                       housing_psa  ...   transit_district vic_age_group  \
# 28218   No level development code  ...  No data available         25-44
# 202348  No level development code  ...  No data available         25-44
#
#         vic_race vic_sex x_coord_cd y_coord_cd   latitude  longitude  \
# 28218      WHITE       F     993443     217663  40.764115 -73.966815
# 202348     WHITE       F     993443     217663  40.764115 -73.966815
#
#                                         lat_lon  \
# 28218   (40.76411453300005, -73.96681541399995)
# 202348  (40.76411453300005, -73.96681541399995)
#
#                             new_georeferenced_column
# 28218   POINT (-73.96681541399995 40.76411453300005)
# 202348  POINT (-73.96681541399995 40.76411453300005)
#
# [2 rows x 36 columns]

# %%
print(df.loc[[202348]], df.loc[[28218]] )
# Out:
#         cmplnt_num  addr_pct_cd    boro_nm cmplnt_fr_dt cmplnt_fr_tm  \
# 202348   927482064           19  MANHATTAN   04/02/2021     17:00:00
#
#        cmplnt_to_dt cmplnt_to_tm crm_atpt_cptd_cd     hadevelopt  \
# 202348   04/02/2021     17:20:00        COMPLETED  Not aplicable
#
#                       housing_psa  ...   transit_district vic_age_group  \
# 202348  No level development code  ...  No data available         25-44
#
#         vic_race vic_sex x_coord_cd y_coord_cd   latitude  longitude  \
# 202348     WHITE       F     993443     217663  40.764115 -73.966815
#
#                                         lat_lon  \
# 202348  (40.76411453300005, -73.96681541399995)
#
#                             new_georeferenced_column
# 202348  POINT (-73.96681541399995 40.76411453300005)
#
# [1 rows x 36 columns]        cmplnt_num  addr_pct_cd    boro_nm cmplnt_fr_dt cmplnt_fr_tm  \
# 28218   927482064           19  MANHATTAN   03/02/2021     17:20:00
#
#       cmplnt_to_dt cmplnt_to_tm crm_atpt_cptd_cd     hadevelopt  \
# 28218   03/02/2021     17:20:00        COMPLETED  Not aplicable
#
#                      housing_psa  ...   transit_district vic_age_group  \
# 28218  No level development code  ...  No data available         25-44
#
#        vic_race vic_sex x_coord_cd y_coord_cd   latitude  longitude  \
# 28218     WHITE       F     993443     217663  40.764115 -73.966815
#
#                                        lat_lon  \
# 28218  (40.76411453300005, -73.96681541399995)
#
#                            new_georeferenced_column
# 28218  POINT (-73.96681541399995 40.76411453300005)
#
# [1 rows x 36 columns]

# %%
print("Shape before deletion")
print(df.shape)
df = df.drop(df.index[202348])
print("Shape after detetion")
print(df.shape)
# Out:
# Shape before deletion
# (204646, 36)
# Shape after detetion
# (204645, 36)

# %% [markdown]
# #### Questions to Ask Our Data
#
# - What types of complaints come into the NYPD sytem?

# %%
cmpl_type = df.ofns_desc.value_counts().reset_index()
cmpl_type = cmpl_type.head(6)
cmpl_type
# Out:
#                             index  ofns_desc
# 0                   PETIT LARCENY      38553
# 1                   HARRASSMENT 2      34303
# 2  CRIMINAL MISCHIEF & RELATED OF      21882
# 3    ASSAULT 3 & RELATED OFFENSES      21758
# 4                   GRAND LARCENY      16152
# 5                  FELONY ASSAULT      10264

# %%
gb_cmpl_type = df.groupby('ofns_desc').agg({'cmplnt_num':'count'}).sort_values(by= 'cmplnt_num',ascending=False)#.plot.bar(color = gr_colors,figsize=(18,20))
gb_cmpl_type.head(6)
# Out:
#                                 cmplnt_num
# ofns_desc
# PETIT LARCENY                        38553
# HARRASSMENT 2                        34303
# CRIMINAL MISCHIEF & RELATED OF       21882
# ASSAULT 3 & RELATED OFFENSES         21758
# GRAND LARCENY                        16152
# FELONY ASSAULT                       10264

# %%
gb_cmpl_top6 = gb_cmpl_type.head(6)

# %%
# function to add value labels
def label_values(a,b):
    for i in range(len(a)):
        plt.text(i, b[i], b[i], ha = 'center')

# %%
# list of complaint types
cmpl_type_list = gb_cmpl_top6.cmplnt_num.index.tolist()
# list of complaints count
cmpl_count_list = list(gb_cmpl_top6.cmplnt_num)

# %%
sns.set_theme(style="whitegrid")
g_colors = 'gmbcyrk'
gb_cmpl_top6.plot(kind = 'bar', figsize = (10,8),color = g_colors)
label_values(cmpl_type_list, cmpl_count_list)
plt.title("Complaint Classification")
plt.xlabel("Complaint Description")
plt.ylabel("Number of Complaints")
plt.xticks(rotation=45, ha='right')
# Out:
# (array([0, 1, 2, 3, 4, 5]), <a list of 6 Text xticklabel objects>)

# %%
ax = sns.barplot(x="ofns_desc", y="index", data=cmpl_type)

# %% [markdown]
# ### PETIT LARCENY
# Under our law, a person is guilty of petit larceny when such
# person steals property.
# A person STEALS PROPERTY and commits larceny when,
# with the intent to deprive another of property or to appropriate the
# same to himself or herself or to a third person, such person
# wrongfully takes, obtains, or withholds such property from an
# owner of the property. 2 2
# PROPERTY means any money, personal property, or thing of value
# OWNER means a person having a right to possession to
# the property superior to that of the person who takes it.
# INTENT means a conscious objective or purpose.
#
# Link to [info](https://www.nycourts.gov/judges/cji/2-PenalLaw/155/155.25.Petit%20Larceny.Revision.pdf)

# %% [markdown]
# #### Question to Ask Our Data
#
# - Race of complaint suspect in the interactions with the NYPD?

# %%
susp_race_df = df['susp_race'].value_counts().reset_index()
susp_race_df
# Out:
#                             index  susp_race
# 0                           BLACK      59064
# 1                         UNKNOWN      49126
# 2                  WHITE HISPANIC      25797
# 3                           WHITE      15291
# 4                  BLACK HISPANIC       8080
# 5        ASIAN / PACIFIC ISLANDER       5900
# 6  AMERICAN INDIAN/ALASKAN NATIVE        302

# %%
gb_race = df.groupby('susp_race').agg({'cmplnt_num':'count'})
gb_race.sort_values(by= 'cmplnt_num', ascending=False, inplace = True)
gb_race
# Out:
#                                 cmplnt_num
# susp_race
# BLACK                                59064
# UNKNOWN                              49126
# WHITE HISPANIC                       25797
# WHITE                                15291
# BLACK HISPANIC                        8080
# ASIAN / PACIFIC ISLANDER              5900
# AMERICAN INDIAN/ALASKAN NATIVE         302

# %%
susp_list = gb_race.cmplnt_num.index.tolist()
count_list = list(gb_race.cmplnt_num)

# %%
gr_colors = 'gmbryck'
gb_race.plot.bar(color = gr_colors,figsize = (10,8), width = .5)
label_values(susp_list, count_list)
plt.title("Race of people interacting with the NYPD as Suspects")
plt.xlabel("Suspect Race")
plt.ylabel("Number of Complaints")
plt.xticks(rotation=45, ha='right')
# Out:
# (array([0, 1, 2, 3, 4, 5, 6]), <a list of 7 Text xticklabel objects>)

# %%
susp_labels = gb_race.cmplnt_num.sort_values().index 
susp_counts = gb_race.cmplnt_num.sort_values()

# %%
the_grid = GridSpec(2, 2)
cmap = plt.get_cmap('Spectral')
colors = [cmap(i) for i in np.linspace(0, 1, 8)]
plt.figure(1, figsize=(20,20))
plt.subplot(the_grid[0, 1], aspect=1, title='Race of Complaint Suspects')
susp_race_ids = plt.pie(susp_counts, labels=susp_labels, autopct='%1.1f%%', shadow=True, colors=colors)
plt.show()

# %% [markdown]
# ### Racial disparity reflected in the data
# ###### Population estimates, July 1, 2019
# ##### New York City, New York has a polulation of 8,336,817
# - White 42.7%
# - Black or African American  24.3%
# - American Indian and Alaska Native  0.4%
# - Asian 14.1%
# - Native Hawaiian and Other Pacific Islander  0.1%
# - Hispanic or Latino 29.1%
# White alone, not Hispanic or Latino  32.1%
#
# link to [info](https://www.census.gov/quickfacts/fact/table/newyorkcitynewyork#)

# %% [markdown]
#  ##  Race and type of complaints

# %%
gb_race_compl = df.groupby(['ofns_desc','susp_race']).agg({'cmplnt_num':'count'})
gb_race_compl.sort_values(by =  'cmplnt_num',ascending = False, inplace = True)
gb_race_compl.head()
# Out:
#                                         cmplnt_num
# ofns_desc                    susp_race
# HARRASSMENT 2                BLACK           13375
# PETIT LARCENY                UNKNOWN         12003
# ASSAULT 3 & RELATED OFFENSES BLACK            9203
# PETIT LARCENY                BLACK            8389
# GRAND LARCENY                UNKNOWN          6885

# %% [markdown]
# ### HARASSMENT IN THE SECOND DEGREE
# Under our law, a person is guilty of Harassment in the
# Second Degree when, with intent to harass, annoy or alarm
# another person, he or she strikes, shoves, kicks or otherwise subjects such other
# person to physical contact, or attempts or threatens to do
# the same.
# follows a person in or about a public place or places.
#
# link to [info](https://nycourts.gov/judges/cji/2-PenalLaw/240/240-26.pdf)

# %%
# Top 5 complaint offenses (race to offense map)
gb_r_c_top5 = gb_race_compl.head()
gb_r_c_top5
# Out:
#                                         cmplnt_num
# ofns_desc                    susp_race
# HARRASSMENT 2                BLACK           13375
# PETIT LARCENY                UNKNOWN         12003
# ASSAULT 3 & RELATED OFFENSES BLACK            9203
# PETIT LARCENY                BLACK            8389
# GRAND LARCENY                UNKNOWN          6885

# %%
gb_r_c_top5.plot.bar(color = g_colors, figsize = (9,7), width = .5)
plt.title("Mapping Type of Complaint to Race")
plt.xlabel("Complaint type/Suspect Race")
plt.ylabel("Number of Complaints")
plt.xticks(rotation=45, ha='right')
# Out:
# (array([0, 1, 2, 3, 4]), <a list of 5 Text xticklabel objects>)

# %% [markdown]
# #### Questions to Ask Our Data
#
# - Is there a difference between boroughs and what complaints go on?

# %%
df.boro_nm.value_counts().reset_index()
# Out:
#            index  boro_nm
# 0       BROOKLYN    58372
# 1      MANHATTAN    49570
# 2         QUEENS    44354
# 3          BRONX    42962
# 4  STATEN ISLAND     9002

# %% [markdown]
# ### Grouping by Borough

# %%
gb_boro = df.groupby(['boro_nm']).agg({'cmplnt_num':'count'})
gb_boro.sort_values(by = 'cmplnt_num', ascending = False,inplace = True)
gb_boro
# Out:
#                cmplnt_num
# boro_nm
# BROOKLYN            58372
# MANHATTAN           49570
# QUEENS              44354
# BRONX               42962
# STATEN ISLAND        9002

# %%
boro_key_list = gb_boro.cmplnt_num.index.tolist()
boro_value_list = list(gb_boro.cmplnt_num)

# %% [markdown]
# ### These Graphs  Misrepresent Data (Bar and Pie)

# %%
gb_boro.plot.bar(color = g_colors, figsize = (9,7), width = .5)
label_values(boro_key_list, boro_value_list)
plt.title("Number of Complaints by Borough")
plt.xlabel("New York Boroughs")
plt.ylabel("Number of Complaints")
plt.xticks(rotation=0, ha='center')
# Out:
# (array([0, 1, 2, 3, 4]), <a list of 5 Text xticklabel objects>)

# %%
boro_labels = gb_boro.cmplnt_num.sort_values().index 
boro_counts = gb_boro.cmplnt_num.sort_values()

# %%
the_grid = GridSpec(2, 2)
cmap = plt.get_cmap('Spectral')
colors = [cmap(i) for i in np.linspace(0, 1, 6)]
plt.figure(1, figsize=(20,20))
plt.subplot(the_grid[0, 1], aspect=1, title='Race of Complaint Suspects')
susp_race_ids = plt.pie(boro_counts, labels=boro_labels, autopct='%1.1f%%', shadow=True, colors=colors)
plt.show()

# %% [markdown]
# ### The Borough results should be presented by rate of complaints per population size

# %%
# How do you calculate rate per population?
# A complaint rate is calculated by dividing the number
# of reported complaints by the total population. The result
# is then multiplied by 100,000. For example, in the course of a year there
# were 58,372 complaint in Brooklyn and the population was
# 2,736,074. This equals a complaint rate of 2133.4 per 100,000.

# %%
bk_result = (58372/2736074)*100000
bk_result
# Out:
# 2133.421829965125

# %%
# Borough population by United States 2020 census
# Queens pop 2405464
# Brooklyn pop 2,736,074 
# Manhattan pop 1,694,251
# Brox pop 1472654
# Staten Island pop 495747
boro_pop_list = [2736074, 1694251, 2405464, 1472654, 495747]
print(boro_pop_list) # borough population list
print(boro_key_list) # borough name list
print(boro_value_list)# total number of complaints
# Out:
# [2736074, 1694251, 2405464, 1472654, 495747]
# ['BROOKLYN', 'MANHATTAN', 'QUEENS', 'BRONX', 'STATEN ISLAND']
# [58372, 49570, 44354, 42962, 9002]

# %% [markdown]
# ### Improve this step by using the new dataframe (df_cmp_boro) as lists

# %%
# Making borough dictionary with name=>complaint_value as key pair
zip_iterator = zip(boro_key_list, boro_value_list)
boro_dict = dict(zip_iterator)
print(boro_dict)

# %%
# Making boro dicitonary with name=>total population as key pair
zip_iterator = zip(boro_key_list, boro_pop_list)
boro_pop_dict = dict(zip_iterator)
print(boro_pop_dict)

# for reference
# how to sort a dict by value
#{key: value for key, value in sorted(boro_pop_dict.items(), key = lambda item: item[1],reverse = True)}

# %%
# Create a function that compares the keys (boro_name) of two dictionaries.
# get the rate list after dividing by population and muliplying by 100,000
# function uses as input two dictionaries(one with total population and one with total number of complaints)
def cmpl_per_100k(dict_cmpl_num, dict_pop_num):
    cmpl_div_list =[]
    for key in dict_cmpl_num: # traverse first dict
        if(key in dict_pop_num and key == key): # compare key from dict1 and dict2
            cmpl_div_list.append(dict_cmpl_num[key]/dict_pop_num[key]) # Divide complaint count by populaion
    cmpl_per_pop = []
    for item in cmpl_div_list:
        cmpl_per_pop.append(int(item * 100000))
    
    return cmpl_per_pop
# function returns the complaint count by borough per 100,000

# %%
cmpl_per = cmpl_per_100k(boro_dict,boro_pop_dict)

# %%
df_cmp_boro = pd.DataFrame({"boro_name":boro_key_list,"complaint_value":cmpl_per})
df_cmp_boro.sort_values(by = "complaint_value",ascending = False, inplace = True)

# %%
# lists to be used as input for function label_values()
boro_list2 = list(df_cmp_boro["boro_name"])
value_list2 = list(df_cmp_boro["complaint_value"])
print(boro_list2)
print(value_list2)
# Out:
# ['MANHATTAN', 'BRONX', 'BROOKLYN', 'QUEENS', 'STATEN ISLAND']
# [2925, 2917, 2133, 1843, 1815]

# %% [markdown]
# ### Better Way is to Represent Number of Complaints per Borough

# %%
fig = plt.figure(figsize = (10,8))
plt.bar('boro_name','complaint_value',data=df_cmp_boro, color=g_colors, width=.5)
label_values(boro_list2, value_list2)
plt.title("Number of Complaints by Borough per 100,000")
plt.xlabel("New York Boroughs")
plt.ylabel("Number of Complaints")
plt.xticks(rotation=0, ha='center')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# ### Groupting by Borough and Complaint Type

# %%
gb_boro_type = df.groupby(['boro_nm','ofns_desc']).agg({'cmplnt_num':'count'})#.sort_values(by= 'cmplnt_num',ascending=False).plot.bar(color = g_colors)
gb_boro_type.sort_values(by = 'cmplnt_num', ascending = False,inplace = True)
#gb_boro.plot.bar(color = g_colors)
gb_boro_type.head(6)
#plt.figsize = (20,20)
# Out:
#                          cmplnt_num
# boro_nm   ofns_desc
# MANHATTAN PETIT LARCENY       11989
# BROOKLYN  PETIT LARCENY       10442
#           HARRASSMENT 2       10137
# QUEENS    PETIT LARCENY        8775
#           HARRASSMENT 2        7723
# BRONX     HARRASSMENT 2        7579

# %% [markdown]
# #### Question to Ask Our Data
#
# - Comparing both genders to see if there any difference of what complaints they deal with.

# %%
df_sex = df.susp_sex.value_counts().reset_index()
df_sex
# Out:
#   index  susp_sex
# 0     M     95883
# 1     U     41832
# 2     F     25845

# %%
gb_sex = (df.groupby(['susp_sex']).agg({'cmplnt_num':'count'}).sort_values(by= 'cmplnt_num',ascending=False))
gb_sex
# Out:
#           cmplnt_num
# susp_sex
# M              95883
# U              41832
# F              25845

# %%
ax = sns.barplot(x="index", y="susp_sex", data=df_sex)

# %%
df.columns
# Out:
# Index(['cmplnt_num', 'addr_pct_cd', 'boro_nm', 'cmplnt_fr_dt', 'cmplnt_fr_tm',
#        'cmplnt_to_dt', 'cmplnt_to_tm', 'crm_atpt_cptd_cd', 'hadevelopt',
#        'housing_psa', 'jurisdiction_code', 'juris_desc', 'ky_cd', 'law_cat_cd',
#        'loc_of_occur_desc', 'ofns_desc', 'parks_nm', 'patrol_boro', 'pd_cd',
#        'pd_desc', 'prem_typ_desc', 'rpt_dt', 'station_name', 'susp_age_group',
#        'susp_race', 'susp_sex', 'transit_district', 'vic_age_group',
#        'vic_race', 'vic_sex', 'x_coord_cd', 'y_coord_cd', 'latitude',
#        'longitude', 'lat_lon', 'new_georeferenced_column'],
#       dtype='object')

# %%
m= df[df['susp_sex']=='M'].reset_index()
f = df[df['susp_sex']=='F'].reset_index()

# %%
plt.figure(figsize=(11,13))
plt.scatter(x=m['longitude'],y=m['latitude'],alpha=.5,s=.05,c='r')
plt.scatter(x=f['longitude'],y=f['latitude'],alpha=.5,s=.05,c='g')
plt.title('Scatter Plot of Complaint Suspect by Gender')
# x = The column name or column position to be used as horizontal coordinates for each point.
# y = The column name or column position to be used as vertical coordinates for each point.
# Out:
# Text(0.5, 1.0, 'Scatter Plot of Complaint Suspect by Gender')

# %% [markdown]
# ### Looking for Info on Age Groups

# %%
df.susp_age_group.value_counts()
# Out:
# UNKNOWN    73280
# 25-44      53173
# 45-64      17882
# 18-24      14712
# <18         2647
# 65+         1849
# 2021          10
# 1017           1
# -969           1
# -973           1
# -941           1
# -947           1
# -975           1
# -966           1
# Name: susp_age_group, dtype: int64

# %%
race_gb = df.groupby('susp_race')['susp_age_group'].value_counts()
race_gb.to_frame()
# Out:
#                                                susp_age_group
# susp_race                      susp_age_group
# AMERICAN INDIAN/ALASKAN NATIVE 25-44                      136
#                                45-64                       58
#                                UNKNOWN                     58
#                                18-24                       40
#                                <18                          7
#                                65+                          3
# ASIAN / PACIFIC ISLANDER       25-44                     2746
#                                45-64                     1158
#                                UNKNOWN                   1102
#                                18-24                      648
#                                65+                        163
#                                <18                         83
# BLACK                          25-44                    25468
#                                UNKNOWN                  15541
#                                45-64                     8367
#                                18-24                     7693
#                                <18                       1357
#                                65+                        632
#                                2021                         3
#                                -966                         1
#                                -969                         1
#                                1017                         1
# BLACK HISPANIC                 25-44                     3829
#                                UNKNOWN                   1669
#                                18-24                     1227
#                                45-64                     1014
#                                <18                        257
#                                65+                         82
#                                -947                         1
#                                2021                         1
# UNKNOWN                        UNKNOWN                  45431
#                                25-44                     2092
#                                45-64                      679
#                                18-24                      619
#                                <18                        185
#                                65+                        116
#                                2021                         4
# WHITE                          25-44                     6492
#                                UNKNOWN                   3994
#                                45-64                     3074
#                                18-24                     1011
#                                65+                        533
#                                <18                        184
#                                2021                         2
#                                -975                         1
# WHITE HISPANIC                 25-44                    12410
#                                UNKNOWN                   5485
#                                45-64                     3532
#                                18-24                     3474
#                                <18                        574
#                                65+                        320
#                                -941                         1
#                                -973                         1

# %%
gb_age_gr = df.groupby(['susp_age_group']).agg({'cmplnt_num':'count'})#.sort_values(by= 'ARREST_KEY',ascending=False))
gb_age_gr.sort_values(by= 'cmplnt_num',ascending = False,inplace = True)

# %%
gb_age_gr = gb_age_gr.head(6)
gb_age_gr.plot()

# %%
# Trying to isolate the borugh
df.columns
# Out:
# Index(['cmplnt_num', 'addr_pct_cd', 'boro_nm', 'cmplnt_fr_dt', 'cmplnt_fr_tm',
#        'cmplnt_to_dt', 'cmplnt_to_tm', 'crm_atpt_cptd_cd', 'hadevelopt',
#        'housing_psa', 'jurisdiction_code', 'juris_desc', 'ky_cd', 'law_cat_cd',
#        'loc_of_occur_desc', 'ofns_desc', 'parks_nm', 'patrol_boro', 'pd_cd',
#        'pd_desc', 'prem_typ_desc', 'rpt_dt', 'station_name', 'susp_age_group',
#        'susp_race', 'susp_sex', 'transit_district', 'vic_age_group',
#        'vic_race', 'vic_sex', 'x_coord_cd', 'y_coord_cd', 'latitude',
#        'longitude', 'lat_lon', 'new_georeferenced_column'],
#       dtype='object')

# %%
df['boro_nm'].value_counts()
# Out:
# BROOKLYN         58372
# MANHATTAN        49570
# QUEENS           44354
# BRONX            42962
# STATEN ISLAND     9002
# Name: boro_nm, dtype: int64

# %%
df.isnull().sum()['boro_nm']
# Out:
# 385

# %%
man_df= df[df['boro_nm']=='MANHATTAN']
man_df.head()
# Out:
#     cmplnt_num  addr_pct_cd    boro_nm cmplnt_fr_dt cmplnt_fr_tm cmplnt_to_dt  \
# 13   957810616           18  MANHATTAN   02/25/2021     18:15:00   02/25/2021
# 14   738990323           25  MANHATTAN   03/09/2021     19:45:00   03/09/2021
# 15   126186881           14  MANHATTAN   03/03/2021     16:17:00          NaN
# 22   270972500           19  MANHATTAN   02/22/2021     11:24:00   02/22/2021
# 26   133888342            6  MANHATTAN   02/13/2021     02:45:00   02/13/2021
#
#    cmplnt_to_tm crm_atpt_cptd_cd     hadevelopt                housing_psa  \
# 13     18:30:00        COMPLETED  Not aplicable  No level development code
# 14     19:50:00        COMPLETED  Not aplicable  No level development code
# 15          NaN        COMPLETED  Not aplicable  No level development code
# 22     11:36:00        COMPLETED  Not aplicable  No level development code
# 26     02:55:00        COMPLETED  Not aplicable  No level development code
#
#     ...   transit_district vic_age_group        vic_race vic_sex x_coord_cd  \
# 13  ...  No data available         25-44  WHITE HISPANIC       F     987287
# 14  ...  No data available       UNKNOWN         UNKNOWN       E    1002641
# 15  ...  No data available       UNKNOWN         UNKNOWN       D     987220
# 22  ...  No data available       UNKNOWN         UNKNOWN       D     998835
# 26  ...  No data available         45-64           BLACK       M     985126
#
#    y_coord_cd   latitude  longitude                                   lat_lon  \
# 13     220178  40.771022 -73.989037   (40.77102181400005, -73.98903697199995)
# 14     231749  40.802763 -73.933573   (40.80276250500003, -73.93357277899997)
# 15     212676  40.750431 -73.989282   (40.75043076800005, -73.98928217599996)
# 22     224880  40.783916 -73.947335  (40.783916057000056, -73.94733504199996)
# 26     207917  40.737369 -73.996840   (40.73736895500008, -73.99684042399997)
#
#                          new_georeferenced_column
# 13   POINT (-73.98903697199995 40.77102181400005)
# 14   POINT (-73.93357277899997 40.80276250500003)
# 15   POINT (-73.98928217599996 40.75043076800005)
# 22  POINT (-73.94733504199996 40.783916057000056)
# 26   POINT (-73.99684042399997 40.73736895500008)
#
# [5 rows x 36 columns]

# %%
# data frames by gender
man_m= man_df[man_df['susp_sex']=='M'].reset_index()
man_f= man_df[man_df['susp_sex']=='F'].reset_index()

# data frames by the top complaint
#PETIT LARCENY
plar= man_df[man_df['ofns_desc']=='PETIT LARCENY'].reset_index()

# %%
plt.figure(figsize=(7,11))
plt.scatter(x=man_m['longitude'],y=man_m['latitude'],alpha=.5,s=.05,c='r')
plt.scatter(x=man_f['longitude'],y=man_f['latitude'],alpha=.5,s=.05,c='g')
plt.title('Scatter Plot of Complaint Suspect by Gender in Manhattan')
# Out:
# Text(0.5, 1.0, 'Scatter Plot of Complaint Suspect by Gender in Manhattan')

# %%
plt.figure(figsize=(7,11))
plt.scatter(x=plar['longitude'],y=plar['latitude'],alpha=.5,s=.05,c='m')
plt.title("Scatter Plot of Complaint Suspect by top complaint 'petit larceny'" )
# Out:
# Text(0.5, 1.0, "Scatter Plot of Complaint Suspect by top complaint 'petit larceny'")

# %%
brooklyn_cond = df['boro_nm']=='BROOKLYN'

# brooklyn dataframe
bk_df = df[brooklyn_cond]

# petit larcerny dataframe from brooklyn df
bk_plar= bk_df[bk_df['ofns_desc']=='PETIT LARCENY'].reset_index()

# %%
plt.figure(figsize=(7,11))
plt.scatter(x=bk_plar['longitude'],y=bk_plar['latitude'],alpha=.5,s=.05,c='r')
plt.title("Scatter Plot of Complaint Suspect by top complaint 'petit larceny'")
# Out:
# Text(0.5, 1.0, "Scatter Plot of Complaint Suspect by top complaint 'petit larceny'")

# %%
queens_cond = df['boro_nm']=='QUEENS'

# queens dataframe
q_df = df[queens_cond]

# %%
# petit larceny dataframe from queens df
q_plar= q_df[q_df['ofns_desc']=='PETIT LARCENY']
type(q_plar)
# Out:
# pandas.core.frame.DataFrame

# %%
plt.figure(figsize=(7,11))
plt.scatter(x=q_plar['longitude'],y=q_plar['latitude'],alpha=.5,s=.05,c='g')
plt.title("Scatter Plot of Complaint Suspect by top complaint 'petit larceny'")
# Out:
# Text(0.5, 1.0, "Scatter Plot of Complaint Suspect by top complaint 'petit larceny'")

# %%
list_of_brs = ['QUEENS','BROOKLYN']
selected_brs = df.boro_nm.isin(list_of_brs)

# dataframe queens and brooklyn
q_bk_df = df[selected_brs]

# %%
q_bk_plar= q_bk_df[q_bk_df['ofns_desc']=='PETIT LARCENY'].reset_index()

# %%
plt.figure(figsize=(7,11))
plt.scatter(x=q_bk_plar['longitude'],y=q_bk_plar['latitude'],alpha=.5,s=.05,c='g')
plt.title("Scatter Plot of Complaint Suspect by top complaint 'petit larceny'")
# Out:
# Text(0.5, 1.0, "Scatter Plot of Complaint Suspect by top complaint 'petit larceny'")

# %%
plt.figure(figsize=(7,11))
plt.scatter(x=bk_plar['longitude'],y=bk_plar['latitude'],alpha=.5,s=.05,c='r')
plt.scatter(x=q_plar['longitude'],y=q_plar['latitude'],alpha=.5,s=.05,c='g')
plt.title("Scatter Plot of Complaint Suspect by top complaint 'petit larceny'")
# Out:
# Text(0.5, 1.0, "Scatter Plot of Complaint Suspect by top complaint 'petit larceny'")

# %%
plt.figure(figsize=(7,11))
plt.scatter(x=bk_plar['longitude'],y=bk_plar['latitude'],alpha=.5,s=.05,c='r')
plt.scatter(x=q_plar['longitude'],y=q_plar['latitude'],alpha=.5,s=.05,c='g')
plt.title("Scatter Plot of Complaint Suspect by top complaint 'petit larceny'")
# Out:
# Text(0.5, 1.0, "Scatter Plot of Complaint Suspect by top complaint 'petit larceny'")

# %%
print ("david is here")
# Out:
# david is here

# %%
q_df.shape
# Out:
# (44354, 36)

# %%
#df.apply(lambda x: func(x['col1'],x['col2']),axis=1)

# %%
q_df["zipcode"] = q_df[0:100].apply(lambda x: get_zip_code(x), axis=1)
# Out:
# /Users/jorgegranda/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
q_df.head()
